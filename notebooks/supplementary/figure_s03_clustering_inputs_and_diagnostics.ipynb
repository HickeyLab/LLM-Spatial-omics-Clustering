# %%
# Supplementary Figure S3A — raw ground-truth cell-type marker dot plot.
# This cell uses the 209,587 non-Noise B004 cells and exactly the 45 H5AD-X
# protein markers. Rows and columns are independently ordered by average-linkage
# clustering with correlation distance, matching the supplied reference panel.
from pathlib import Path
import sys

# Locate the repository whether Jupyter starts at the repo root or below it.
candidate_roots = [Path.cwd(), *Path.cwd().parents]
repository_root = next((path for path in candidate_roots if (path / 'configs/figure_s03.yaml').is_file()), None)
if repository_root is None:
    raise FileNotFoundError('Could not locate configs/figure_s03.yaml')
source_directory = repository_root / 'src'
if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

from llm_spatial_omics_clustering.figure_s03 import run_panel_a

# The runner validates the Figure 2 cohort, recomputes the summary, and writes
# an audit table, PNG/PDF panels, and a provenance record.
panel_a_outputs = run_panel_a(repository_root=repository_root)
{name: str(Path(path).relative_to(repository_root)) for name, path in panel_a_outputs.items()}
# Out:
# {'summary_csv': 'outputs/supplementary/figure_s03/figure_s03a_marker_dotplot_summary.csv',
#  'panel_png': 'outputs/supplementary/figure_s03/figure_s03a_marker_dotplot.png',
#  'panel_pdf': 'outputs/supplementary/figure_s03/figure_s03a_marker_dotplot.pdf',
#  'provenance_json': 'outputs/supplementary/figure_s03/figure_s03a_provenance.json'}

# %%
# Supplementary Figure S3B — all eight B004 tissue regions.
# Every raw label, including Noise, is shown at native H5AD x/y coordinates.
# The y coordinate is intentionally not inverted, and region titles are omitted
# to match the supplied 2x4 composite.
from pathlib import Path
import sys

candidate_roots = [Path.cwd(), *Path.cwd().parents]
repository_root = next((path for path in candidate_roots if (path / 'configs/figure_s03.yaml').is_file()), None)
if repository_root is None:
    raise FileNotFoundError('Could not locate configs/figure_s03.yaml')
source_directory = repository_root / 'src'
if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

from llm_spatial_omics_clustering.figure_s03 import run_panel_b

panel_b_outputs = run_panel_b(repository_root=repository_root)
{name: str(Path(path).relative_to(repository_root)) for name, path in panel_b_outputs.items()}
# Out:
# {'region_summary_csv': 'outputs/supplementary/figure_s03/figure_s03b_region_summary.csv',
#  'panel_png': 'outputs/supplementary/figure_s03/figure_s03b_all_tissue_regions.png',
#  'panel_pdf': 'outputs/supplementary/figure_s03/figure_s03b_all_tissue_regions.pdf',
#  'provenance_json': 'outputs/supplementary/figure_s03/figure_s03b_provenance.json'}

# %%
# Supplementary Figure S3C — raw cell-type composition of selected clusters.
# The assignments come directly from Figure 2, so PIXIE is the canonical
# image-native TIFF result. This deliberately differs from the screenshot's
# older table-level PIXIE partition. FlowSOM displays its 60 largest clusters.
from pathlib import Path
import sys

candidate_roots = [Path.cwd(), *Path.cwd().parents]
repository_root = next((path for path in candidate_roots if (path / 'configs/figure_s03.yaml').is_file()), None)
if repository_root is None:
    raise FileNotFoundError('Could not locate configs/figure_s03.yaml')
source_directory = repository_root / 'src'
if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

from llm_spatial_omics_clustering.figure_s03 import run_panel_c

panel_c_outputs = run_panel_c(repository_root=repository_root)
{name: str(Path(path).relative_to(repository_root)) for name, path in panel_c_outputs.items()}
# Out:
# {'composition_csv': 'outputs/supplementary/figure_s03/figure_s03c_cluster_composition.csv',
#  'panel_png': 'outputs/supplementary/figure_s03/figure_s03c_cluster_composition.png',
#  'panel_pdf': 'outputs/supplementary/figure_s03/figure_s03c_cluster_composition.pdf',
#  'provenance_json': 'outputs/supplementary/figure_s03/figure_s03c_provenance.json'}

# %%
# Supplementary Figure S3D — recovered FlowSOM requested-k purity sweep.
# This cell reproduces the supplied curve from its frozen, hash-validated table.
# Important: this archived exploratory sweep (variance selection + PCA) is not
# the final 45-marker, robust-scaled K=300 FlowSOM method. No durable generator
# exists, so it is an illustration only, not tuning or validation of the final
# method. Requested k=350 corresponds to effective k=324 in the frozen table.
from pathlib import Path
import sys

candidate_roots = [Path.cwd(), *Path.cwd().parents]
repository_root = next((path for path in candidate_roots if (path / 'configs/figure_s03.yaml').is_file()), None)
if repository_root is None:
    raise FileNotFoundError('Could not locate configs/figure_s03.yaml')
source_directory = repository_root / 'src'
if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

from llm_spatial_omics_clustering.figure_s03 import run_panel_d

panel_d_outputs = run_panel_d(repository_root=repository_root)
{name: str(Path(path).relative_to(repository_root)) for name, path in panel_d_outputs.items()}
# Out:
# {'sweep_csv': 'outputs/supplementary/figure_s03/figure_s03d_flowsom_cluster_sweep.csv',
#  'panel_png': 'outputs/supplementary/figure_s03/figure_s03d_flowsom_cluster_sweep.png',
#  'panel_pdf': 'outputs/supplementary/figure_s03/figure_s03d_flowsom_cluster_sweep.pdf',
#  'provenance_json': 'outputs/supplementary/figure_s03/figure_s03d_provenance.json'}

# %%
# Supplementary Figure S3E — six clustering metric distributions.
# ARI/AMI are region-level; Shannon and purity are cluster-level; F1/recall
# are raw-cell-type-level after a global retrospective cluster-majority map.
# All metrics use 27 raw non-Noise labels and Figure 2's canonical assignments.
from pathlib import Path
import sys

candidate_roots = [Path.cwd(), *Path.cwd().parents]
repository_root = next((path for path in candidate_roots if (path / 'configs/figure_s03.yaml').is_file()), None)
if repository_root is None:
    raise FileNotFoundError('Could not locate configs/figure_s03.yaml')
source_directory = repository_root / 'src'
if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

from llm_spatial_omics_clustering.figure_s03 import run_panel_e

panel_e_outputs = run_panel_e(repository_root=repository_root)
{name: str(Path(path).relative_to(repository_root)) for name, path in panel_e_outputs.items()}
# Out:
# {'metrics_csv': 'outputs/supplementary/figure_s03/figure_s03e_clustering_metrics.csv',
#  'panel_png': 'outputs/supplementary/figure_s03/figure_s03e_clustering_metrics.png',
#  'panel_pdf': 'outputs/supplementary/figure_s03/figure_s03e_clustering_metrics.pdf',
#  'provenance_json': 'outputs/supplementary/figure_s03/figure_s03e_provenance.json'}
