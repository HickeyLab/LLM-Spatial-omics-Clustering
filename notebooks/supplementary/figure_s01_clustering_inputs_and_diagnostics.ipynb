# %%
# Supplementary Figure 1A — raw ground-truth cell-type marker dot plot.
# This cell uses the 209,587 non-Noise B004 cells and exactly the 45 H5AD-X
# protein markers. Rows and columns are independently ordered by average-linkage
# clustering with correlation distance, matching the supplied reference panel.
from pathlib import Path
import sys

# Locate the repository whether Jupyter starts at the repo root or below it.
candidate_roots = [Path.cwd(), *Path.cwd().parents]
repository_root = next((path for path in candidate_roots if (path / 'configs/figure_s01.yaml').is_file()), None)
if repository_root is None:
    raise FileNotFoundError('Could not locate configs/figure_s01.yaml')
source_directory = repository_root / 'src'
if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

from llm_spatial_omics_clustering.figure_s01 import run_panel_a

# The runner validates the Figure 2 cohort, recomputes the summary, and writes
# an audit table, PNG/PDF panels, and a provenance record.
panel_a_outputs = run_panel_a(repository_root=repository_root)
panel_a_outputs
# Out:
# {'summary_csv': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01a_marker_dotplot_summary.csv'),
#  'panel_png': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01a_marker_dotplot.png'),
#  'panel_pdf': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01a_marker_dotplot.pdf'),
#  'provenance_json': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01a_provenance.json')}

# %%
# Supplementary Figure 1B — all eight B004 tissue regions.
# Every raw label, including Noise, is shown at native H5AD x/y coordinates.
# The y coordinate is intentionally not inverted, and region titles are omitted
# to match the supplied 2x4 composite.
from pathlib import Path
import sys

candidate_roots = [Path.cwd(), *Path.cwd().parents]
repository_root = next((path for path in candidate_roots if (path / 'configs/figure_s01.yaml').is_file()), None)
if repository_root is None:
    raise FileNotFoundError('Could not locate configs/figure_s01.yaml')
source_directory = repository_root / 'src'
if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

from llm_spatial_omics_clustering.figure_s01 import run_panel_b

panel_b_outputs = run_panel_b(repository_root=repository_root)
panel_b_outputs
# Out:
# {'region_summary_csv': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01b_region_summary.csv'),
#  'panel_png': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01b_all_tissue_regions.png'),
#  'panel_pdf': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01b_all_tissue_regions.pdf'),
#  'provenance_json': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01b_provenance.json')}

# %%
# Supplementary Figure 1C — raw cell-type composition of selected clusters.
# The assignments come directly from Figure 2, so PIXIE is the canonical
# image-native TIFF result. This deliberately differs from the screenshot's
# older table-level PIXIE partition. FlowSOM displays its 60 largest clusters.
from pathlib import Path
import sys

candidate_roots = [Path.cwd(), *Path.cwd().parents]
repository_root = next((path for path in candidate_roots if (path / 'configs/figure_s01.yaml').is_file()), None)
if repository_root is None:
    raise FileNotFoundError('Could not locate configs/figure_s01.yaml')
source_directory = repository_root / 'src'
if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

from llm_spatial_omics_clustering.figure_s01 import run_panel_c

panel_c_outputs = run_panel_c(repository_root=repository_root)
panel_c_outputs
# Out:
# {'composition_csv': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01c_cluster_composition.csv'),
#  'panel_png': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01c_cluster_composition.png'),
#  'panel_pdf': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01c_cluster_composition.pdf'),
#  'provenance_json': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01c_provenance.json')}

# %%
# Supplementary Figure 1D — recovered FlowSOM requested-k purity sweep.
# This cell reproduces the supplied curve from its frozen, hash-validated table.
# Important: the sweep was exploratory (variance selection + PCA), not a sweep
# of Figure 2's final MDI-weighted/no-PCA FlowSOM method. The provenance JSON
# preserves that VERIFY gap, and records that requested k=350 means effective k=324.
from pathlib import Path
import sys

candidate_roots = [Path.cwd(), *Path.cwd().parents]
repository_root = next((path for path in candidate_roots if (path / 'configs/figure_s01.yaml').is_file()), None)
if repository_root is None:
    raise FileNotFoundError('Could not locate configs/figure_s01.yaml')
source_directory = repository_root / 'src'
if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

from llm_spatial_omics_clustering.figure_s01 import run_panel_d

panel_d_outputs = run_panel_d(repository_root=repository_root)
panel_d_outputs
# Out:
# {'sweep_csv': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01d_flowsom_cluster_sweep.csv'),
#  'panel_png': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01d_flowsom_cluster_sweep.png'),
#  'panel_pdf': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01d_flowsom_cluster_sweep.pdf'),
#  'provenance_json': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01d_provenance.json')}

# %%
# Supplementary Figure 1E — six clustering metric distributions.
# ARI/AMI are region-level; Shannon and purity are cluster-level; F1/recall
# are raw-cell-type-level after a global retrospective cluster-majority map.
# All metrics use 27 raw non-Noise labels and Figure 2's canonical assignments.
from pathlib import Path
import sys

candidate_roots = [Path.cwd(), *Path.cwd().parents]
repository_root = next((path for path in candidate_roots if (path / 'configs/figure_s01.yaml').is_file()), None)
if repository_root is None:
    raise FileNotFoundError('Could not locate configs/figure_s01.yaml')
source_directory = repository_root / 'src'
if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

from llm_spatial_omics_clustering.figure_s01 import run_panel_e

panel_e_outputs = run_panel_e(repository_root=repository_root)
panel_e_outputs
# Out:
# {'metrics_csv': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01e_clustering_metrics.csv'),
#  'panel_png': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01e_clustering_metrics.png'),
#  'panel_pdf': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01e_clustering_metrics.pdf'),
#  'provenance_json': PosixPath('/Users/zacharydeutsch/Desktop/cell_masks/LLM-Spatial-omics-Clustering/outputs/supplementary/figure_s01/figure_s01e_provenance.json')}
