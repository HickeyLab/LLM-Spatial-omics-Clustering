# %%
# Figure 4A — end-to-end Leiden-to-GPT workflow.
# This is the only local-only panel: it draws the frozen analysis contract
# and does not load the H5AD, read an LLM cache, or call an external API.
from pathlib import Path
import sys

# Locate the repository whether Jupyter starts here or in a child directory.
candidate_roots = [Path.cwd(), *Path.cwd().parents]
repository_root = next((path for path in candidate_roots if (path / 'configs/figure_04.yaml').is_file()), None)
if repository_root is None:
    raise FileNotFoundError('Could not locate configs/figure_04.yaml')
source_directory = repository_root / 'src'
if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

from llm_spatial_omics_clustering.figure_04 import run_panel_a

panel_a_outputs = run_panel_a(repository_root=repository_root)
panel_a_outputs

# %%
# Figure 4B — row-normalized cell-type confusion matrix.
# The key is deliberately a placeholder in the tracked notebook. With a real
# OPENAI_API_KEY, this reuses (or creates once) Figure 3's single optimized,
# reasoning-enabled GPT annotation for the 55 fixed Leiden clusters.
from pathlib import Path
import os
import sys

candidate_roots = [Path.cwd(), *Path.cwd().parents]
repository_root = next((path for path in candidate_roots if (path / 'configs/figure_04.yaml').is_file()), None)
if repository_root is None:
    raise FileNotFoundError('Could not locate configs/figure_04.yaml')
source_directory = repository_root / 'src'
if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

from llm_spatial_omics_clustering.figure_04 import run_panel_b

openai_api_key = os.getenv('OPENAI_API_KEY', 'PASTE_OPENAI_API_KEY_HERE')
# force_refresh=False lets later panel cells reuse the exact same cached map.
panel_b_outputs = run_panel_b(
    {'openai': openai_api_key},
    repository_root=repository_root,
    force_refresh=False,
)
panel_b_outputs

# %%
# Figure 4C — pooled and tissue-region-specific one-vs-rest F1 scores.
# Gray bars use all 220,082 B004 cells; colored points recalculate F1 within
# each File_ID. A region point is omitted only when that truth class is absent.
from pathlib import Path
import os
import sys

candidate_roots = [Path.cwd(), *Path.cwd().parents]
repository_root = next((path for path in candidate_roots if (path / 'configs/figure_04.yaml').is_file()), None)
if repository_root is None:
    raise FileNotFoundError('Could not locate configs/figure_04.yaml')
source_directory = repository_root / 'src'
if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

from llm_spatial_omics_clustering.figure_04 import run_panel_c

openai_api_key = os.getenv('OPENAI_API_KEY', 'PASTE_OPENAI_API_KEY_HERE')
panel_c_outputs = run_panel_c(
    {'openai': openai_api_key},
    repository_root=repository_root,
    force_refresh=False,
)
panel_c_outputs

# %%
# Figure 4D — representative annotation-, clustering-, and mixed-loss clusters.
# Examples are selected deterministically from the current shared GPT mapping;
# legacy cluster IDs are not hard-coded because the supplied composite mixed maps.
from pathlib import Path
import os
import sys

candidate_roots = [Path.cwd(), *Path.cwd().parents]
repository_root = next((path for path in candidate_roots if (path / 'configs/figure_04.yaml').is_file()), None)
if repository_root is None:
    raise FileNotFoundError('Could not locate configs/figure_04.yaml')
source_directory = repository_root / 'src'
if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

from llm_spatial_omics_clustering.figure_04 import run_panel_d

openai_api_key = os.getenv('OPENAI_API_KEY', 'PASTE_OPENAI_API_KEY_HERE')
panel_d_outputs = run_panel_d(
    {'openai': openai_api_key},
    repository_root=repository_root,
    force_refresh=False,
)
panel_d_outputs

# %%
# Figure 4E — cohort-wide correctness and upper-bound loss decomposition.
# Values are recomputed from the shared annotation map. No percentage from the
# reference screenshot is copied or hard-coded into this analysis.
from pathlib import Path
import os
import sys

candidate_roots = [Path.cwd(), *Path.cwd().parents]
repository_root = next((path for path in candidate_roots if (path / 'configs/figure_04.yaml').is_file()), None)
if repository_root is None:
    raise FileNotFoundError('Could not locate configs/figure_04.yaml')
source_directory = repository_root / 'src'
if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

from llm_spatial_omics_clustering.figure_04 import run_panel_e

openai_api_key = os.getenv('OPENAI_API_KEY', 'PASTE_OPENAI_API_KEY_HERE')
panel_e_outputs = run_panel_e(
    {'openai': openai_api_key},
    repository_root=repository_root,
    force_refresh=False,
)
panel_e_outputs

# %%
# Figure 4F — correctness and loss fractions for every Leiden cluster.
# Each horizontal bar sums to one: observed correctness + annotation loss
# + clustering loss. These are arithmetic upper-bound components, not causal labels.
from pathlib import Path
import os
import sys

candidate_roots = [Path.cwd(), *Path.cwd().parents]
repository_root = next((path for path in candidate_roots if (path / 'configs/figure_04.yaml').is_file()), None)
if repository_root is None:
    raise FileNotFoundError('Could not locate configs/figure_04.yaml')
source_directory = repository_root / 'src'
if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

from llm_spatial_omics_clustering.figure_04 import run_panel_f

openai_api_key = os.getenv('OPENAI_API_KEY', 'PASTE_OPENAI_API_KEY_HERE')
panel_f_outputs = run_panel_f(
    {'openai': openai_api_key},
    repository_root=repository_root,
    force_refresh=False,
)
panel_f_outputs
