# %% [markdown]
# # Figure 4 — End-to-end Leiden–GPT pipeline
#
# **Status:** Structure-only notebook. No analysis has been implemented.

# %% [markdown]
# ## Notebook contract
#
# - **Purpose:** Generate all panels for manuscript Figure 4.
# - **Inputs:** To be declared before implementation.
# - **Outputs:** Repository-relative `outputs/figure_04/`.
# - **Prompts:** Load version-controlled prompt templates from `prompts/` once implemented.
# - **Shared code:** Import reusable functions from `src/` once implemented.

# %% [markdown]
# ## Setup and provenance
#
# TODO: Declare configuration, data versions, GPT model and prompt versions, and random seeds.

# %% [markdown]
# ## Data preparation
#
# TODO: Load and validate Leiden clusters, reference labels, and cached GPT annotations.

# %% [markdown]
# ## Figure panels
#
# - [ ] **A:** End-to-end Leiden clustering and GPT annotation workflow.
# - [ ] **B:** Row-normalized cell-type confusion matrix.
# - [ ] **C:** Cell-type-specific F1 scores.
# - [ ] **D:** Representative annotation-, clustering-, and mixed-error clusters.
# - [ ] **E:** Overall fractions of correctly annotated and lost cells.
# - [ ] **F:** Outcome fractions for each Leiden cluster.

# %% [markdown]
# ## Export
#
# TODO: Export final panels and any supporting tables to `outputs/figure_04/`.

# %% [markdown]
# ## Validation
#
# TODO: Add figure-specific integrity, reproducibility, model-provenance, and visual checks.
