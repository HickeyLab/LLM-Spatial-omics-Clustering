# %% [markdown]
# # Figure 1 — REDSEA spillover correction
#
# **Status:** `VERIFY:` source unavailable; Figure 1 is omitted from the current V3 publication packet.

# %% [markdown]
# ## Notebook contract
#
# - **Purpose:** Preserve the Figure 1 scope without fabricating a reconstruction.
# - **Inputs:** The historical REDSEA before/after CSV inputs are not available.
# - **Outputs:** Repository-relative `outputs/figure_01/`.
# - **Shared code:** Import reusable functions from `src/` once implemented.

# %% [markdown]
# ## Setup and provenance
#
# `VERIFY:` Declare configuration, data versions, software versions, and random seeds only after the source inputs are recovered.

# %% [markdown]
# ## Data preparation
#
# `VERIFY:` No Figure 1 source inputs are loaded in the current packet.

# %% [markdown]
# ## Figure panels
#
# All panels remain `VERIFY:` until the REDSEA source contract is supplied.

# %% [markdown]
# ## Export
#
# No Figure 1 outputs are generated. The current packet intentionally contains no Figure 1 placeholder.

# %% [markdown]
# ## Validation
#
# Validation is blocked by the unavailable source inputs; do not mark Figure 1 complete from the placeholder notebook.
