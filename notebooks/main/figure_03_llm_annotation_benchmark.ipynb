# %%
# Figure 3, Panel A — marker-summary, LLM annotation, and evaluation workflow
# This is the only Figure 3 panel that does not use an LLM. It documents the
# complete dependency chain from Figure 2 clusters to the Figure 3 metrics.
from pathlib import Path
import os
import sys
from IPython.display import Image, display

# Locate the repository whether Jupyter was launched from the repository root
# or from a directory inside it; keep all imports and outputs repository-local.
repository_override = os.getenv("FIGURE_REPOSITORY_ROOT")
search_start = Path(repository_override).expanduser().resolve() if repository_override else Path.cwd().resolve()
repository_root = next(
    (candidate for candidate in (search_start, *search_start.parents)
     if (candidate / "configs" / "figure_03.yaml").is_file()),
    None,
)
if repository_root is None:
    raise FileNotFoundError("Run from inside the repository or set FIGURE_REPOSITORY_ROOT.")
if str(repository_root / "src") not in sys.path:
    sys.path.insert(0, str(repository_root / "src"))

from llm_spatial_omics_clustering.figure_03 import run_panel_a

# Render manuscript PNG/PDF files and a provenance JSON in outputs/figure_03/.
panel_a_outputs = run_panel_a(repository_root)
display(Image(filename=str(panel_a_outputs["png"])))
panel_a_outputs

# %%
# Figure 3, Panel B — protein-marker optimization
# The clustering assignments are loaded from Figure 2, including TIFF-derived
# PIXIE. The eight B004 regions are paired before/after optimization.
from pathlib import Path
import os
import sys
from IPython.display import Image, display

repository_override = os.getenv("FIGURE_REPOSITORY_ROOT")
search_start = Path(repository_override).expanduser().resolve() if repository_override else Path.cwd().resolve()
repository_root = next(
    (candidate for candidate in (search_start, *search_start.parents)
     if (candidate / "configs" / "figure_03.yaml").is_file()),
    None,
)
if repository_root is None:
    raise FileNotFoundError("Run from inside the repository or set FIGURE_REPOSITORY_ROOT.")
if str(repository_root / "src") not in sys.path:
    sys.path.insert(0, str(repository_root / "src"))

from llm_spatial_omics_clustering.figure_03 import run_panel_b

# Export OPENAI_API_KEY (or use your notebook secret manager). The tracked
# placeholder is rejected before data loading, cache access, or panel creation.
api_keys = {"openai": os.getenv("OPENAI_API_KEY", "PASTE_OPENAI_API_KEY_HERE")}
panel_b_outputs = run_panel_b(
    api_keys,
    repository_root,
    force_refresh=False,  # Reuse only contract-matched cached responses.
)
display(Image(filename=str(panel_b_outputs["png"])))
panel_b_outputs

# %%
# Figure 3, Panel C — representative stromal-cell spatial distribution
# The fixed B004 window compares ground truth with correctly recovered Stroma
# before/after optimization; it reuses Panel B's contract-matched caches.
from pathlib import Path
import os
import sys
from IPython.display import Image, display

repository_override = os.getenv("FIGURE_REPOSITORY_ROOT")
search_start = Path(repository_override).expanduser().resolve() if repository_override else Path.cwd().resolve()
repository_root = next(
    (candidate for candidate in (search_start, *search_start.parents)
     if (candidate / "configs" / "figure_03.yaml").is_file()),
    None,
)
if repository_root is None:
    raise FileNotFoundError("Run from inside the repository or set FIGURE_REPOSITORY_ROOT.")
if str(repository_root / "src") not in sys.path:
    sys.path.insert(0, str(repository_root / "src"))

from llm_spatial_omics_clustering.figure_03 import run_panel_c

# A real environment-provided key is required even with a matching cache.
api_keys = {"openai": os.getenv("OPENAI_API_KEY", "PASTE_OPENAI_API_KEY_HERE")}
panel_c_outputs = run_panel_c(api_keys, repository_root, force_refresh=False)
display(Image(filename=str(panel_c_outputs["png"])))
panel_c_outputs

# %%
# Figure 3, Panel D — cell-level reasoning versus non-reasoning
# Each regional point is the mean annotation accuracy across the four LLMs,
# normalized to that region and clustering method's theoretical upper bound.
# Gemini's historical minimal-thinking arm may still reason; the plot marks it.
from pathlib import Path
import os
import sys
from IPython.display import Image, display

repository_override = os.getenv("FIGURE_REPOSITORY_ROOT")
search_start = Path(repository_override).expanduser().resolve() if repository_override else Path.cwd().resolve()
repository_root = next(
    (candidate for candidate in (search_start, *search_start.parents)
     if (candidate / "configs" / "figure_03.yaml").is_file()),
    None,
)
if repository_root is None:
    raise FileNotFoundError("Run from inside the repository or set FIGURE_REPOSITORY_ROOT.")
if str(repository_root / "src") not in sys.path:
    sys.path.insert(0, str(repository_root / "src"))

from llm_spatial_omics_clustering.figure_03 import run_panel_d

# Read secrets from the environment; never paste credentials into this file.
api_keys = {
    "gemini": os.getenv("GEMINI_API_KEY", "PASTE_GEMINI_API_KEY_HERE"),
    "openai": os.getenv("OPENAI_API_KEY", "PASTE_OPENAI_API_KEY_HERE"),
    "anthropic": os.getenv("ANTHROPIC_API_KEY", "PASTE_ANTHROPIC_API_KEY_HERE"),
    "deepseek": os.getenv("DEEPSEEK_API_KEY", "PASTE_DEEPSEEK_API_KEY_HERE"),
}
panel_d_outputs = run_panel_d(api_keys, repository_root, force_refresh=False)
display(Image(filename=str(panel_d_outputs["png"])))
panel_d_outputs

# %%
# Figure 3, Panel E — cluster-level reasoning versus non-reasoning
# This cell uses the same model responses as Panel D but evaluates the mean
# within-cluster annotation accuracy instead of cell-weighted accuracy.
# Gemini's historical minimal-thinking arm may still reason; the plot marks it.
from pathlib import Path
import os
import sys
from IPython.display import Image, display

repository_override = os.getenv("FIGURE_REPOSITORY_ROOT")
search_start = Path(repository_override).expanduser().resolve() if repository_override else Path.cwd().resolve()
repository_root = next(
    (candidate for candidate in (search_start, *search_start.parents)
     if (candidate / "configs" / "figure_03.yaml").is_file()),
    None,
)
if repository_root is None:
    raise FileNotFoundError("Run from inside the repository or set FIGURE_REPOSITORY_ROOT.")
if str(repository_root / "src") not in sys.path:
    sys.path.insert(0, str(repository_root / "src"))

from llm_spatial_omics_clustering.figure_03 import run_panel_e

api_keys = {
    "gemini": os.getenv("GEMINI_API_KEY", "PASTE_GEMINI_API_KEY_HERE"),
    "openai": os.getenv("OPENAI_API_KEY", "PASTE_OPENAI_API_KEY_HERE"),
    "anthropic": os.getenv("ANTHROPIC_API_KEY", "PASTE_ANTHROPIC_API_KEY_HERE"),
    "deepseek": os.getenv("DEEPSEEK_API_KEY", "PASTE_DEEPSEEK_API_KEY_HERE"),
}
panel_e_outputs = run_panel_e(api_keys, repository_root, force_refresh=False)
display(Image(filename=str(panel_e_outputs["png"])))
panel_e_outputs

# %%
# Figure 3, Panel F — cell-level LLM-by-clustering-method heatmap
# Reasoning-condition predictions are scored globally as a percentage of each
# Figure 2 clustering method's cell-level theoretical upper bound.
from pathlib import Path
import os
import sys
from IPython.display import Image, display

repository_override = os.getenv("FIGURE_REPOSITORY_ROOT")
search_start = Path(repository_override).expanduser().resolve() if repository_override else Path.cwd().resolve()
repository_root = next(
    (candidate for candidate in (search_start, *search_start.parents)
     if (candidate / "configs" / "figure_03.yaml").is_file()),
    None,
)
if repository_root is None:
    raise FileNotFoundError("Run from inside the repository or set FIGURE_REPOSITORY_ROOT.")
if str(repository_root / "src") not in sys.path:
    sys.path.insert(0, str(repository_root / "src"))

from llm_spatial_omics_clustering.figure_03 import run_panel_f

api_keys = {
    "gemini": os.getenv("GEMINI_API_KEY", "PASTE_GEMINI_API_KEY_HERE"),
    "openai": os.getenv("OPENAI_API_KEY", "PASTE_OPENAI_API_KEY_HERE"),
    "anthropic": os.getenv("ANTHROPIC_API_KEY", "PASTE_ANTHROPIC_API_KEY_HERE"),
    "deepseek": os.getenv("DEEPSEEK_API_KEY", "PASTE_DEEPSEEK_API_KEY_HERE"),
}
panel_f_outputs = run_panel_f(api_keys, repository_root, force_refresh=False)
display(Image(filename=str(panel_f_outputs["png"])))
panel_f_outputs

# %%
# Figure 3, Panel G — cluster-level LLM-by-clustering-method heatmap
# This is the cluster-balanced counterpart to Panel F and reuses the same
# optimized reasoning-condition annotation caches.
from pathlib import Path
import os
import sys
from IPython.display import Image, display

repository_override = os.getenv("FIGURE_REPOSITORY_ROOT")
search_start = Path(repository_override).expanduser().resolve() if repository_override else Path.cwd().resolve()
repository_root = next(
    (candidate for candidate in (search_start, *search_start.parents)
     if (candidate / "configs" / "figure_03.yaml").is_file()),
    None,
)
if repository_root is None:
    raise FileNotFoundError("Run from inside the repository or set FIGURE_REPOSITORY_ROOT.")
if str(repository_root / "src") not in sys.path:
    sys.path.insert(0, str(repository_root / "src"))

from llm_spatial_omics_clustering.figure_03 import run_panel_g

api_keys = {
    "gemini": os.getenv("GEMINI_API_KEY", "PASTE_GEMINI_API_KEY_HERE"),
    "openai": os.getenv("OPENAI_API_KEY", "PASTE_OPENAI_API_KEY_HERE"),
    "anthropic": os.getenv("ANTHROPIC_API_KEY", "PASTE_ANTHROPIC_API_KEY_HERE"),
    "deepseek": os.getenv("DEEPSEEK_API_KEY", "PASTE_DEEPSEEK_API_KEY_HERE"),
}
panel_g_outputs = run_panel_g(api_keys, repository_root, force_refresh=False)
display(Image(filename=str(panel_g_outputs["png"])))
panel_g_outputs

# %%
# Figure 3, Panel H — absolute annotation purity by cell type for Leiden
# Rows report cell-type recall for each reasoning-condition LLM; the side bars
# show the non-Noise B004 ground-truth cell counts used in evaluation.
from pathlib import Path
import os
import sys
from IPython.display import Image, display

repository_override = os.getenv("FIGURE_REPOSITORY_ROOT")
search_start = Path(repository_override).expanduser().resolve() if repository_override else Path.cwd().resolve()
repository_root = next(
    (candidate for candidate in (search_start, *search_start.parents)
     if (candidate / "configs" / "figure_03.yaml").is_file()),
    None,
)
if repository_root is None:
    raise FileNotFoundError("Run from inside the repository or set FIGURE_REPOSITORY_ROOT.")
if str(repository_root / "src") not in sys.path:
    sys.path.insert(0, str(repository_root / "src"))

from llm_spatial_omics_clustering.figure_03 import run_panel_h

api_keys = {
    "gemini": os.getenv("GEMINI_API_KEY", "PASTE_GEMINI_API_KEY_HERE"),
    "openai": os.getenv("OPENAI_API_KEY", "PASTE_OPENAI_API_KEY_HERE"),
    "anthropic": os.getenv("ANTHROPIC_API_KEY", "PASTE_ANTHROPIC_API_KEY_HERE"),
    "deepseek": os.getenv("DEEPSEEK_API_KEY", "PASTE_DEEPSEEK_API_KEY_HERE"),
}
panel_h_outputs = run_panel_h(api_keys, repository_root, force_refresh=False)
display(Image(filename=str(panel_h_outputs["png"])))
panel_h_outputs

# %%
# Figure 3, Panel I — upper-bound-normalized purity by cell type for Leiden
# The CSV preserves raw ratios; the heatmap clips its display scale to 0–100%
# and records any ratios above 100% in the panel provenance.
from pathlib import Path
import os
import sys
from IPython.display import Image, display

repository_override = os.getenv("FIGURE_REPOSITORY_ROOT")
search_start = Path(repository_override).expanduser().resolve() if repository_override else Path.cwd().resolve()
repository_root = next(
    (candidate for candidate in (search_start, *search_start.parents)
     if (candidate / "configs" / "figure_03.yaml").is_file()),
    None,
)
if repository_root is None:
    raise FileNotFoundError("Run from inside the repository or set FIGURE_REPOSITORY_ROOT.")
if str(repository_root / "src") not in sys.path:
    sys.path.insert(0, str(repository_root / "src"))

from llm_spatial_omics_clustering.figure_03 import run_panel_i

api_keys = {
    "gemini": os.getenv("GEMINI_API_KEY", "PASTE_GEMINI_API_KEY_HERE"),
    "openai": os.getenv("OPENAI_API_KEY", "PASTE_OPENAI_API_KEY_HERE"),
    "anthropic": os.getenv("ANTHROPIC_API_KEY", "PASTE_ANTHROPIC_API_KEY_HERE"),
    "deepseek": os.getenv("DEEPSEEK_API_KEY", "PASTE_DEEPSEEK_API_KEY_HERE"),
}
panel_i_outputs = run_panel_i(api_keys, repository_root, force_refresh=False)
display(Image(filename=str(panel_i_outputs["png"])))
panel_i_outputs

# %%
# Figure 3, Panel J — cell-level purity for reasoning LLMs and consensus
# The historical vote uses truth-tuned tie priorities and is exploratory.
# The cell exports sensitivity results for all 24 provider orders.
from pathlib import Path
import os
import sys
from IPython.display import Image, display

repository_override = os.getenv("FIGURE_REPOSITORY_ROOT")
search_start = Path(repository_override).expanduser().resolve() if repository_override else Path.cwd().resolve()
repository_root = next(
    (candidate for candidate in (search_start, *search_start.parents)
     if (candidate / "configs" / "figure_03.yaml").is_file()),
    None,
)
if repository_root is None:
    raise FileNotFoundError("Run from inside the repository or set FIGURE_REPOSITORY_ROOT.")
if str(repository_root / "src") not in sys.path:
    sys.path.insert(0, str(repository_root / "src"))

from llm_spatial_omics_clustering.figure_03 import run_panel_j

api_keys = {
    "gemini": os.getenv("GEMINI_API_KEY", "PASTE_GEMINI_API_KEY_HERE"),
    "openai": os.getenv("OPENAI_API_KEY", "PASTE_OPENAI_API_KEY_HERE"),
    "anthropic": os.getenv("ANTHROPIC_API_KEY", "PASTE_ANTHROPIC_API_KEY_HERE"),
    "deepseek": os.getenv("DEEPSEEK_API_KEY", "PASTE_DEEPSEEK_API_KEY_HERE"),
}
panel_j_outputs = run_panel_j(api_keys, repository_root, force_refresh=False)
display(Image(filename=str(panel_j_outputs["png"])))
panel_j_outputs

# %%
# Figure 3, Panel K — cluster-level purity for reasoning LLMs and consensus
# This cluster-balanced view uses the same four annotations and the historical,
# truth-tuned tie policy as Panel J; all 24 provider orders are exported.
from pathlib import Path
import os
import sys
from IPython.display import Image, display

repository_override = os.getenv("FIGURE_REPOSITORY_ROOT")
search_start = Path(repository_override).expanduser().resolve() if repository_override else Path.cwd().resolve()
repository_root = next(
    (candidate for candidate in (search_start, *search_start.parents)
     if (candidate / "configs" / "figure_03.yaml").is_file()),
    None,
)
if repository_root is None:
    raise FileNotFoundError("Run from inside the repository or set FIGURE_REPOSITORY_ROOT.")
if str(repository_root / "src") not in sys.path:
    sys.path.insert(0, str(repository_root / "src"))

from llm_spatial_omics_clustering.figure_03 import run_panel_k

api_keys = {
    "gemini": os.getenv("GEMINI_API_KEY", "PASTE_GEMINI_API_KEY_HERE"),
    "openai": os.getenv("OPENAI_API_KEY", "PASTE_OPENAI_API_KEY_HERE"),
    "anthropic": os.getenv("ANTHROPIC_API_KEY", "PASTE_ANTHROPIC_API_KEY_HERE"),
    "deepseek": os.getenv("DEEPSEEK_API_KEY", "PASTE_DEEPSEEK_API_KEY_HERE"),
}
panel_k_outputs = run_panel_k(api_keys, repository_root, force_refresh=False)
display(Image(filename=str(panel_k_outputs["png"])))
panel_k_outputs

# %%
# Figure 3, Panel L — spatial agreement across annotation methods
# Deterministic 900–1,100-cell windows are selected by modal agreement among
# the four LLM votes over all B004 cells; truth and consensus do not select them.
from pathlib import Path
import os
import sys
from IPython.display import Image, display

repository_override = os.getenv("FIGURE_REPOSITORY_ROOT")
search_start = Path(repository_override).expanduser().resolve() if repository_override else Path.cwd().resolve()
repository_root = next(
    (candidate for candidate in (search_start, *search_start.parents)
     if (candidate / "configs" / "figure_03.yaml").is_file()),
    None,
)
if repository_root is None:
    raise FileNotFoundError("Run from inside the repository or set FIGURE_REPOSITORY_ROOT.")
if str(repository_root / "src") not in sys.path:
    sys.path.insert(0, str(repository_root / "src"))

from llm_spatial_omics_clustering.figure_03 import run_panel_l

api_keys = {
    "gemini": os.getenv("GEMINI_API_KEY", "PASTE_GEMINI_API_KEY_HERE"),
    "openai": os.getenv("OPENAI_API_KEY", "PASTE_OPENAI_API_KEY_HERE"),
    "anthropic": os.getenv("ANTHROPIC_API_KEY", "PASTE_ANTHROPIC_API_KEY_HERE"),
    "deepseek": os.getenv("DEEPSEEK_API_KEY", "PASTE_DEEPSEEK_API_KEY_HERE"),
}
panel_l_outputs = run_panel_l(api_keys, repository_root, force_refresh=False)
display(Image(filename=str(panel_l_outputs["png"])))
panel_l_outputs
