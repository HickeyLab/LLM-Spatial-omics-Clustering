# %% [markdown]
# # Figure 3 — LLM annotation benchmark
#
# **Status:** Structure-only notebook. No analysis has been implemented.

# %% [markdown]
# ## Notebook contract
#
# - **Purpose:** Generate all panels for manuscript Figure 3.
# - **Inputs:** To be declared before implementation.
# - **Outputs:** Repository-relative `outputs/figure_03/`.
# - **Prompts:** Load version-controlled prompt templates from `prompts/` once implemented.
# - **Shared code:** Import reusable functions from `src/` once implemented.

# %% [markdown]
# ## Setup and provenance
#
# TODO: Declare configuration, data versions, model identifiers, prompt versions, and random seeds.

# %% [markdown]
# ## Data preparation
#
# TODO: Load and validate clustering summaries, marker inputs, and cached LLM responses.

# %% [markdown]
# ## Figure panels
#
# - [ ] **A:** Marker-summary, LLM annotation, and evaluation workflow.
# - [ ] **B:** Annotation purity before and after marker-threshold optimization.
# - [ ] **C:** Representative stromal-cell spatial distributions.
# - [ ] **D:** Cell-level purity for non-reasoning and reasoning prompts.
# - [ ] **E:** Cluster-level purity for non-reasoning and reasoning prompts.
# - [ ] **F:** Cell-level purity by LLM and clustering method.
# - [ ] **G:** Cluster-level purity by LLM and clustering method.
# - [ ] **H:** Absolute annotation purity by cell type for Leiden clusters.
# - [ ] **I:** Upper-bound annotation purity by cell type for Leiden clusters.
# - [ ] **J:** Cell-level purity for individual LLMs and consensus.
# - [ ] **K:** Cluster-level purity for individual LLMs and consensus.
# - [ ] **L:** High- and low-agreement spatial annotation maps.

# %% [markdown]
# ## Export
#
# TODO: Export final panels and any supporting tables to `outputs/figure_03/`.

# %% [markdown]
# ## Validation
#
# TODO: Add figure-specific integrity, reproducibility, model-provenance, and visual checks.
