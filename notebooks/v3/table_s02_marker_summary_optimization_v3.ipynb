# %%
# Table S2. Retrospective optimization of cluster marker-summary parameters.
from pathlib import Path
import sys

workspace = next((parent for parent in (Path.cwd(), *Path.cwd().parents) if (parent / 'v3_scripts').is_dir()), None)
if workspace is None:
    raise FileNotFoundError('Could not locate the cell_masks workspace root')
sys.path.insert(0, str(workspace))
from v3_scripts.build_v3_table02_marker_summary_optimization import build

result = build(recompose_packet=True, write_notebook=False)
print(result)
