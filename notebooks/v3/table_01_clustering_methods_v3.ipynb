# %% [markdown]
# # Table S1. Final clustering configurations and hyperparameters used in the comparative benchmark.
#
# This table is source-backed by `Supplementary_Table_clustering_hyperparameters_v3.csv` and is rendered as a compact 7-inch-wide publication page after S2.

# %%
from pathlib import Path
import csv
from IPython.display import display, HTML

CSV_PATH = Path('Supplementary_Table_clustering_hyperparameters_v3.csv')
if not CSV_PATH.is_file():
    CSV_PATH = Path('../../../../Supplementary_Table_clustering_hyperparameters_v3.csv')
with CSV_PATH.open(newline='', encoding='utf-8') as handle:
    rows = list(csv.DictReader(handle))
display(HTML('<table><tr><th>Clustering method</th><th>Clusters</th><th>Parameters</th></tr>' + ''.join(
    f"<tr><td>{row['Method']}</td><td>{row['Clusters']}</td><td>{row['Hyperparameters']}</td></tr>" for row in rows
) + '</table>'))
