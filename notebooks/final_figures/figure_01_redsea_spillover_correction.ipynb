# %% [markdown]
# # Figure 1 final: REDSEA spillover correction
#
# **Status:** `VERIFY:` source unavailable; Figure 1 is intentionally omitted from the current final publication packet.
#
# The historical source notebook contains no executable reconstruction, and the expected REDSEA before/after CSV inputs are absent. This notebook records the omission without fabricating panels or metrics.

# %% [markdown]
# ## Current packet contract
#
# The canonical final packet contains Figures 2--4, Supplementary Figures S3--S4, Tables S1--S2, and Supplementary Note 1. Figure 1 will remain closed until its source inputs and reconstruction contract are supplied.
